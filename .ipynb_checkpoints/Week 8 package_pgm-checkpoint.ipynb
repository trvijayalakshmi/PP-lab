# %%
# importing from the package
import Week_8_package.arithmetic as m1
import Week_8_package.geometry1 as m2

print("Addition:", m1.add(10, 5))
print("Multiplication:", m1.mul(10, 5))

area_t, peri_t = m2.triangle(4,6,5)
print(f"Area and perimeter of a triangle are: {area_t}, {peri_t}")

area_r, peri_r = m2.rectangle(6,4)
print(f"Area and perimeter of a rectangle are: {area_r}, {peri_r}")

area_s, peri_s = m2.square(10)
print(f"Area and perimeter of a square are: {area_s}, {peri_s}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <module>
#       1 # importing from the package
# ----> 2 import Week_8_package.arithmetic as m1
#       3 import Week_8_package.geometry1 as m2
#       5 print("Addition:", m1.add(10, 5))
#
# File ~/Documents/Python Programming MR25/PP lab/Week_8_package/__init__.py:7, in <module>
#       1 #!/usr/bin/env python
#       2 # coding: utf-8
#       3
#       4 # In[3]:
# ----> 7 from arithmetic import *
#       8 from geometry1 import *
#
# ModuleNotFoundError: No module named 'arithmetic'
