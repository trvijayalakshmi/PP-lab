# %% [raw]
# 1. What is a Package?
#
# A package in Python is a collection of modules (Python files).
#
# It helps organize code in a hierarchical structure.
#
# A package is simply a directory that contains an __init__.py file (can be empty).
#
# Packages allow you to reuse code, avoid conflicts, and keep projects well-structured.

# %% [raw]
# 2. Structure of a Package
#
# For example, suppose we want a package for math utilities:
#
# my_package/
# │
# ├── __init__.py        # Makes this directory a package
# ├── addition.py        # Module 1
# └── multiplication.py  # Module 2

# %%
# Create addition.py file
def add(a, b):
    return a + b

# %%
# Create multiplication.py file
def multiply(a, b):
    return a * b

# %%
# Create init.py file
# This file can be empty or used to import functions
from .addition import add
from .multiplication import multiply

# %%
Using the Package

# %%
# Importing from the package
from my_package import add, multiply

print("Addition:", add(10, 5))
print("Multiplication:", multiply(10, 5))
